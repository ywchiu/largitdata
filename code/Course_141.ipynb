# %%
import requests
res = requests.get('http://210.65.131.75/SERVICE/QueryPrice/4f8f75bc2a2af4d72eb9cabd08bb8a5b?q=')
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{'AA11': '其他',
#   'AA12': '',
#   'a': '羅斯福路三段211~240號',
#   'b': '住宅大樓(11層含以上有電梯)',
#   'bs': '73.05%',
#   'city': 'A',
#   'cp': '',
#   'e': '11003',
#   'el': '有',
#   'es': '',
#   'f': '二層/十二層',
#   'fi': '',
#   'g': '33',
#   'id': '0',
#   'j': '2',
#   'k': '1',
#   'l': '0',
#   'lat': 25.01966736947408,
#   'lon': 121.5298838591888,
#   'm': '有',
#   'p': '698,469',
#   'pimg': 'bt_05.png',
#   'r': 28,
#   's': '54.40',
#   'sq': 'AH7Tnlz6tpBLt+47lLEgJXCECPL8MiXPQTjMlW6ENMI=',
#   't': '房地(土地+建物)',
#   'tp': '3,800',
#   'type': 'Biz',
#   'v': '4房2廳2衛有隔間'},
#  {'AA11': '其他',
#   'AA12': '',
#   'a': '延吉街151~180號',
#   'b': '華廈(10層含以下有電梯)',
#   'bs': '46.20%',
#   'city': 'A',
#   'cp': '',
#   'e': '11003',
#   'el': '有',
#   'es': '',
#   'f': '三層/五層',
#   'fi': '',
#   'g': '24',
#   'id': '1',
#   'j': '1',
#   'k': '1',
#   'l': '0',
#   'lat': 25.03915363847286,
#   'lon': 121.55522101668707,
#   'm': '有',
#   'p': '330,817',
#   'pimg': 'bt_06.png',
# ...
