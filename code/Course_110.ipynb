# %% [markdown]
# ## 假如有天屈中恆、宋少卿、鈕承澤一起出演一部電影，你能分辨誰是誰嗎？

# %%
from PIL import Image
Image.open('whoami.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=398x505 at 0x10828ACF8>

# %%
import requests
res = requests.get('https://www.google.com.tw/search?ei=MswPXJnSDMaT8wWwoozQDA&yv=3&q=%E9%88%95%E6%89%BF%E6%BE%A4&tbm=isch&vet=10ahUKEwiZs6TsgJjfAhXGybwKHTARA8oQuT0IMigB.MswPXJnSDMaT8wWwoozQDA.i&ved=0ahUKEwiZs6TsgJjfAhXGybwKHTARA8oQuT0IMigB&ijn=1&start=100&asearch=ichunk&async=_id:rg_s,_pms:s,_fmt:pc')

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
for ele in soup.select('img'):
    print(ele.get('src'))
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTF51AWPYAP_jzrOtICFsglfipZn6zMkTXH9r2BQX7ri3Mhzg_o
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSk8pkq0xX6KfiQdf6n7Y8gtndsq0t5BfYKz7ZikI71elePr0UK
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkdj8_B3FGc9lraPNREgOkhLXrYKms7zSqYOp_bRrxsmZdfewwCg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTAhmiHbb5yS6OLHLugi8wIaAsv2-btyFyaSoFfixqcOzrGJ_IK7Q
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6mpds3PHgl5_eQhbc29_h3oAue-cvY5RV3hcJgpmpL6ma_m0C
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQh1bSsNIhpoGUMoAF0pj81dqRm5F5drRf3jHY9u2g5FzC3SWqb
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRK_gmVrb0yfwDtE3Wm9uOkPPqbRmhwF5KfZ-VJxSIxtvlRdMmqDA
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQw2QAj6i-vqdxTwbke1KF4z-Nms8TKy4GqHlZqoX4uJPtZM-KtGg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTR8hLsCoglCZU9tfUnYgH4Pb89ImrJWbSHVQmKnQnnI1Ab36_e
# ...

# %%
with open('1.jpg', 'wb') as f:
    res = requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTF51AWPYAP_jzrOtICFsglfipZn6zMkTXH9r2BQX7ri3Mhzg_o')
    f.write(res.content)

# %%
from PIL import Image
Image.open('1.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168 at 0x109730DA0>

# %%
dataurl = 'https://www.google.com.tw/search?ei=MswPXJnSDMaT8wWwoozQDA&yv=3&q={}&tbm=isch&vet=10ahUKEwiZs6TsgJjfAhXGybwKHTARA8oQuT0IMigB.MswPXJnSDMaT8wWwoozQDA.i&ved=0ahUKEwiZs6TsgJjfAhXGybwKHTARA8oQuT0IMigB&ijn=1&start={}&asearch=ichunk&async=_id:rg_s,_pms:s,_fmt:pc'

def getIdolImg(keyword, dstpath):
    for i in range(3):
        res = requests.get(dataurl.format(keyword, i * 100))
        soup = BeautifulSoup(res.text, 'lxml')
        for ele in soup.select('img'):
            imgurl = ele.get('src')
            fname  = imgurl.split('tbn:')[1]
            with open(dstpath + fname + '.jpg', 'wb') as f:
                res2 = requests.get(imgurl)
                f.write(res2.content)

# %%
import os
os.mkdir('idol1/')

# %%
getIdolImg('鈕承澤', 'idol1/')
