# %%
import requests
res = requests.get('https://www.tej.com.tw/webtej/doc/uid.htm')

# %%
res.encoding = 'big5'
#res.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
table = soup.select('table')

# %%
import re
stockids = re.findall('(\d+)',table[1].text)

# %%
len(stockids)
# Out:
# 647

# %%
stockids
# Out:
# ['1101',
#  '1102',
#  '1103',
#  '1104',
#  '1107',
#  '1109',
#  '1110',
#  '1201',
#  '1203',
#  '1204',
#  '1207',
#  '1210',
#  '1212',
#  '1213',
#  '1215',
#  '1216',
#  '1217',
#  '1218',
#  '1219',
#  '1220',
#  '1221',
#  '1224',
#  '1225',
#  '1227',
#  '1228',
#  '1229',
#  '1231',
#  '1232',
#  '1233',
#  '1234',
#  '1235',
#  '1236',
#  '1301',
#  '1303',
#  '1304',
#  '1305',
#  '1306',
#  '1307',
#  '1308',
#  '1309',
#  '1310',
#  '1311',
#  '1312',
#  '1313',
#  '1314',
#  '1315',
#  '1316',
#  '1319',
#  '1321',
#  '1323',
#  '1324',
#  '1325',
#  '1326',
#  '1402',
#  '1407',
#  '1408',
#  '1409',
#  '1410',
#  '1413',
#  '1414',
#  '1416',
#  '1417',
#  '1418',
#  '1419',
#  '1423',
#  '1432',
#  '1434',
#  '1435',
#  '1436',
#  '1437',
#  '1438',
#  '1439',
#  '1440',
#  '1441',
#  '1442',
#  '1443',
#  '1444',
#  '1445',
#  '1446',
#  '1447',
#  '1449',
#  '1450',
#  '1451',
#  '1452',
#  '1453',
#  '1454',
#  '1455',
#  '1456',
#  '1457',
#  '1458',
# ...
