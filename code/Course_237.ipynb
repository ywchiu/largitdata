# %%
import requests
res = requests.get('https://www.moneydj.com/kmdj/news/newsreallist.aspx?a=trends')
#res.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
domain = 'https://www.moneydj.com/'
for url in soup.select('.forumgrid tr a'):
    print(domain + url.get('href'))
# Out:
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=8fabff04-1694-49e5-8239-94c211612545
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=98c28cc7-3c46-45a4-bca6-24b93e17b24d
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=53bd8e2b-ce2d-44b5-9efe-0712a7305a09
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=346b52c0-f669-4fc4-89af-c78d1cbfef58
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=9fc9e2b3-aae3-401b-85bb-5de2d7368bba
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=f85ec86a-59d2-4084-b638-7b28fe4489c2
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=af5ee3e5-bafb-4a5c-a616-1b543dfece07
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=9f788c33-12b7-4fc4-828a-516c869c0048
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=e7276fdf-47ba-4e98-bd67-c7044a3c328b
# https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=e2ad49a7-ed57-4933-9968-a2a16f2b8f21
# ...

# %%
res2 = requests.get('https://www.moneydj.com//kmdj/news/newsviewer.aspx?a=8fabff04-1694-49e5-8239-94c211612545')
soup2 = BeautifulSoup(res2.text, 'lxml')

# %%
soup2.select_one('h1').text
# Out:
# '\n菲律賓近台灣處實彈軍演 強化捍衛領土實力'

# %%
soup2.select_one('article').text
# Out:
# '\n\n南海局勢升溫，菲律賓最近在靠近台灣的呂宋島北端舉行一連串軍演，假想「來自海上侵略者的入侵」。在此同時，澳洲一艘軍艦14日在行經日本專屬經濟水域時，因為螺旋槳遭漁網纏住故障，潛水員下水排除時遭到附近的中國軍艦連續操作聲納，導致潛水員受到輕傷，澳洲批評中方的行為「不安全且不專業」。「沒人想開戰」 菲總統會習近平盼緩和南海緊張近日菲律賓部隊在呂宋島北端舉行陸海空軍聯合作戰演習，假想「來自海上侵略者的入侵」。演習在現任總統小馬可仕（Ferdinand Marcos Jr.）的家鄉北伊羅科斯省舉行，非常靠近台灣，同時參演的還有美軍陸戰隊跟日本自衛隊。有鑑於南海情勢升溫，菲律賓總統小馬可仕17日在舊金山APEC會見中國國家主席習近平，希望能緩和區域緊張，小馬可仕直言「我認為沒有人想發動戰爭」。不過另一場衝突卻在菲律賓海發生。中艦聲納致潛水員受傷 澳洲批不安全不專業一艘澳洲的護衛艦土烏巴號在日本的專屬經濟水域執行聯合國制裁北韓任務，因為螺旋槳遭到漁網纏住故障，潛水員下水排除時遭到附近的中國驅逐艦連續操作聲納，導致潛水員聽力受到輕傷，引發澳洲的不滿。根據《7NEWS Australia》報導指出，澳洲國防部長馬勒斯直指，「這是不安全且不專業的行為。」澳洲總理艾班尼斯（AnthonyAlbanese）最近才剛訪中會見習近平，又邀請中國總理李強訪澳，希望能重啟外交以及經貿，不料又發生了海上的不友善事件，艾班尼斯跟習近平在APEC握手時雖然沒有多說什麼，不過澳洲政府的不滿可以說是溢於言表。國際中心／林信安 編撰\u3000責任編輯／吳苡榛（本文由 台視新聞 授權轉載）\r\n                    \r\n\r\n                '

# %%
def get_content(url):
    dic = {}
    res2 = requests.get(url)
    soup2 = BeautifulSoup(res2.text, 'lxml')
    dic['title'] = soup2.select_one('h1').text
    dic['article'] = soup2.select_one('article').text
    return dic

# %%
domain = 'https://www.moneydj.com/'
news = []
for url in soup.select('.forumgrid tr a'):
    news.append(get_content(domain + url.get('href')))

# %%
news[0]
# Out:
# {'title': '\n菲律賓近台灣處實彈軍演 強化捍衛領土實力',
#  'article': '\n\n南海局勢升溫，菲律賓最近在靠近台灣的呂宋島北端舉行一連串軍演，假想「來自海上侵略者的入侵」。在此同時，澳洲一艘軍艦14日在行經日本專屬經濟水域時，因為螺旋槳遭漁網纏住故障，潛水員下水排除時遭到附近的中國軍艦連續操作聲納，導致潛水員受到輕傷，澳洲批評中方的行為「不安全且不專業」。「沒人想開戰」 菲總統會習近平盼緩和南海緊張近日菲律賓部隊在呂宋島北端舉行陸海空軍聯合作戰演習，假想「來自海上侵略者的入侵」。演習在現任總統小馬可仕（Ferdinand Marcos Jr.）的家鄉北伊羅科斯省舉行，非常靠近台灣，同時參演的還有美軍陸戰隊跟日本自衛隊。有鑑於南海情勢升溫，菲律賓總統小馬可仕17日在舊金山APEC會見中國國家主席習近平，希望能緩和區域緊張，小馬可仕直言「我認為沒有人想發動戰爭」。不過另一場衝突卻在菲律賓海發生。中艦聲納致潛水員受傷 澳洲批不安全不專業一艘澳洲的護衛艦土烏巴號在日本的專屬經濟水域執行聯合國制裁北韓任務，因為螺旋槳遭到漁網纏住故障，潛水員下水排除時遭到附近的中國驅逐艦連續操作聲納，導致潛水員聽力受到輕傷，引發澳洲的不滿。根據《7NEWS Australia》報導指出，澳洲國防部長馬勒斯直指，「這是不安全且不專業的行為。」澳洲總理艾班尼斯（AnthonyAlbanese）最近才剛訪中會見習近平，又邀請中國總理李強訪澳，希望能重啟外交以及經貿，不料又發生了海上的不友善事件，艾班尼斯跟習近平在APEC握手時雖然沒有多說什麼，不過澳洲政府的不滿可以說是溢於言表。國際中心／林信安 編撰\u3000責任編輯／吳苡榛（本文由 台視新聞 授權轉載）\r\n                    \r\n\r\n                '}

# %%
import pandas
df = pandas.DataFrame(news)

# %%
df
# Out:
#                                       title  \
# 0                    \n菲律賓近台灣處實彈軍演 強化捍衛領土實力
# 1                 \n波音787「夢幻客機」首度降落南極 創2新紀錄
# 2              \n談以巴衝突 拜登：結束後應由巴勒斯坦權力機構統一治理
# 3              \nSpaceX星艦火箭再次試射！抵達太空後失聯自行引爆
# 4                   \n馬斯克挺反猶太言論引撻伐 多家企業撤X廣告
# 5                  \n張忠謀與拜登「非正式寒暄」 和習近平零互動！
# 6   \n「ChatGPT之父」、OpenAI執行長阿特曼被控不坦誠 遭董事會開除！
# 7                \n張忠謀出席APEC晚宴  認「拜習會」增台海穩定
# 8                  \n閃婚才3個半月！「花滑王子」羽生結弦宣布離婚
# 9                    \n景氣最壞已過！富邦金總座：明年配息望更高
# 10                \n大樂透頭獎連9槓！感恩加碼200萬元送出12組
# 11                 \n拜登脫稿稱習近平「獨裁者」 布林肯秒變苦瓜臉
# 12                \n不甩習籲「停止武裝台灣」 美防長：加速武器交付
# 13       \n星巴克員工開店喊「不做了」！超過5000人罷工抗議薪資、人手不足
# 14                  \n奪加薩港控制權 以軍：快摧毀哈瑪斯軍事系統
# 15                      \n芝加哥通勤電車撞除雪車 釀38人傷
# 16            \n拜習會／觸及台灣大選 白宮官員：拜登要習近平尊重勝選人
# 17                    \n連14槓！ 威力彩下期頭獎飆9.5億元
# 18                \n緬甸內戰升溫！ 200萬人流離失所引聯合國關注
# 19         \n南韓大學聯考登場！公務車、警車載考生趕考 英聽全境飛機禁起降
#
# ...

# %%
df.to_csv('moneydj.csv')

# %%
res3 = requests.get('https://www.ctee.com.tw/livenews/world')

# %%
#res3.text

# %%
! curl --proxy brd.superproxy.io:22225 --proxy-user brd-customer-hl_4b18b654-zone-unblocker:4mfb8bo01key -k https://www.ctee.com.tw/livenews/world
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head>
# <meta charset="utf-8">
# <meta charset="utf-8">
# <title>國際 - 即時 - 工商時報</title>
# <meta content name="description">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta name="robots" content="index,follow,noarchive">
# <link rel="canonical" href="https://www.ctee.com.tw/livenews/world">
#
# <meta property="og:url" itemprop="url" content="https://www.ctee.com.tw/livenews">
# <meta property="og:title" itemprop="name" content="總覽 - 即時 - 工商時報">
# <meta property="og:description" itemprop="description" content="總覽 - 即時 - 工商時報">
# <meta property="og:image" itemprop="image" content="https://static.ctee.com.tw/img/ctee-logo-main.png">
# <meta property="og:image:width" content="1200">
# <meta property="og:image:height" content="600">
# <meta name="twitter:card" content="summary_large_image">
# <meta property="og:type" content="article">
# ...

# %%
import requests

# Proxy configuration
proxies = {
    'http': 'http://brd-customer-hl_4b18b654-zone-unblocker:4mfb8bo01key@brd.superproxy.io:22225',
    'https': 'https://brd-customer-hl_4b18b654-zone-unblocker:4mfb8bo01key@brd.superproxy.io:22225',
}

# URL to be accessed
url = 'https://www.ctee.com.tw/livenews/world'

# Making the GET request
response = requests.get(url, proxies=proxies, verify=False)
response.encoding = 'utf-8'
# Printing the response
print(response.text)
# Out:
# /Users/david/.pyenv/versions/3.8.10/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'brd.superproxy.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head>
# <meta charset="utf-8">
# <meta charset="utf-8">
# <title>國際 - 即時 - 工商時報</title>
# <meta content name="description">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta name="robots" content="index,follow,noarchive">
# <link rel="canonical" href="https://www.ctee.com.tw/livenews/world">
#
# <meta property="og:url" itemprop="url" content="https://www.ctee.com.tw/livenews">
# <meta property="og:title" itemprop="name" content="總覽 - 即時 - 工商時報">
# ...
