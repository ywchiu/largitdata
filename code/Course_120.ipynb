# %%
import requests
res = requests.get('https://search.taobao.tw/catalog/?_keyori=ss&ajax=true&from=input&page=2&q=iphone')

# %%
jd = res.json()

# %%
import pandas
df = pandas.DataFrame(jd['mods']['listItems'])

# %%
df.head()
# Out:
#                                        addToCartSkus     brandId brandName  \
# 0  [{'sku': '83321640_TW-932481340', 'skuId': '93...  1028900965     APPLE
# 1  [{'sku': '82167114_TW-931804078', 'skuId': '93...  1028900965     APPLE
# 2  [{'sku': '88149004_TW-962187300', 'skuId': '96...   233768734  Epiphone
# 3  [{'sku': '82944331_TW-931868558', 'skuId': '93...  1028900965     APPLE
# 4  [{'sku': '13552842_TW-137576116', 'skuId': '13...   853760877      CYSY
#
#                        categories           cheapest_sku  \
# 0            [30000002, 30000003]  83321640_TW-932481340
# 1            [30000002, 30000003]  82167114_TW-931804078
# 2            [30000002, 30000003]  88149004_TW-962187300
# 3  [30007430, 41000003, 41000100]  82944331_TW-931868558
# 4  [30000002, 30011161, 30011170]  13552842_TW-137576116
#
#                                           clickTrace  \
# 0  query:iphone;nid:83321640;src:LazadaMainSrp;rn...
# 1  query:iphone;nid:82167114;src:LazadaMainSrp;rn...
# 2  query:iphone;nid:88149004;src:LazadaMainSrp;rn...
# 3  query:iphone;nid:82944331;src:LazadaMainSrp;rn...
# 4  query:iphone;nid:13552842;src:LazadaMainSrp;rn...
#
#                                          description  \
# 0  [特惠新品是當初原廠製造出來要讓有問題的手機去原廠更換的備用全新機, 盒裝沒有封裝 全新配件...
# 1                                               [現貨]
# 2                                 [CP值高，IPhone 8 系列]
# 3                     [本賣場為【一元清空購物車】活動賣場，非參與活動者請勿下單]
# 4                                [3D 全包邊炫紫抗藍光高畫質防指紋]
#
#                                                icons  \
# 0  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 1  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 2  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 3  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
# 4  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
#
#                                                image  inStock  ... review  \
# 0  https://img-ovs.alicdn.com/p/7ca690232851478e1...     True  ...      0
# 1  https://img-ovs.alicdn.com/p/ceba2149567da509e...     True  ...      0
# 2  https://img-ovs.alicdn.com/p/824f9bb8ca744a7b3...     True  ...      0
# 3  https://img-ovs.alicdn.com/p/a1b0acf6ba224926f...     True  ...      0
# 4  https://img-ovs.alicdn.com/other/gsp/525514623...     True  ...      0
#
#         sellerId  sellerName          sku      skuId  \
# 0  2000001297007   高雄樂3C-玉竹店  83321640_TW  932481340
# 1  2000000874156   威訊3C手機批發網  82167114_TW  931804078
# 2  2000001927454  iphone二手專賣  88149004_TW  962187300
# 3  2000001432124         淘台郎  82944331_TW  931868558
# 4  2000000295003      淘寶海外精選  13552842_TW  137576116
#
#                                                 skus   tItemType  \
# 0                  [{'id': '83321640_TW-932481340'}]  nt_product
# 1                  [{'id': '82167114_TW-931804078'}]  nt_product
# 2  [{'id': '88149004_TW-962187300'}, {'id': '8814...  nt_product
# 3                  [{'id': '82944331_TW-931868558'}]  nt_product
# 4  [{'id': '13552842_TW-137576118'}, {'id': '1355...  nt_product
#
#                                               thumbs  \
# 0  [{'image': 'https://img-ovs.alicdn.com/p/7ca69...
# 1  [{'image': 'https://img-ovs.alicdn.com/p/ceba2...
# 2  [{'image': 'https://img-ovs.alicdn.com/p/824f9...
# 3  [{'image': 'https://img-ovs.alicdn.com/p/a1b0a...
# 4  [{'image': 'https://img-ovs.alicdn.com/other/g...
#
#                                             utLogMap                voucherId
# 0  {'x_object_type': 'item', 'x_item_ids': '83321...
# 1  {'x_object_type': 'item', 'x_item_ids': '82167...
# 2  {'x_object_type': 'item', 'x_item_ids': '88149...
# 3  {'x_object_type': 'item', 'x_item_ids': '82944...
# 4  {'x_object_type': 'item', 'x_item_ids': '13552...
#
# [5 rows x 33 columns]

# %%
df.sort_values('price', ascending=False).head()
# Out:
#                                         addToCartSkus    brandId  brandName  \
# 30  [{'sku': '42908281_TW-517706862', 'skuId': '51...      29534      other
# 32  [{'sku': '60982667_TW-759052797', 'skuId': '75...  317256761  Hope Year
# 12  [{'sku': '67172723_TW-835224364', 'skuId': '83...    6564500   No Brand
# 38  [{'sku': '53098018_TW-653764337', 'skuId': '65...      29534      other
# 22  [{'sku': '22886572_TW-252282990', 'skuId': '25...      29534      other
#
#                         categories           cheapest_sku  \
# 30  [30000002, 30011161, 30011170]  42908281_TW-517706862
# 32  [30000002, 30011161, 30011170]  60982667_TW-759052797
# 12  [30000002, 30011161, 30011170]  67172723_TW-835224364
# 38  [30000002, 30011161, 30011170]  53098018_TW-653764337
# 22  [30000002, 30011161, 30011170]  22886572_TW-252282990
#
#                                            clickTrace  \
# 30  query:iphone;nid:42908281;src:LazadaMainSrp;rn...
# 32  query:iphone;nid:60982667;src:LazadaMainSrp;rn...
# 12  query:iphone;nid:67172723;src:LazadaMainSrp;rn...
# 38  query:iphone;nid:53098018;src:LazadaMainSrp;rn...
# 22  query:iphone;nid:22886572;src:LazadaMainSrp;rn...
#
#                                           description  \
# 30  [品牌: other/其他, 型號: E5053, 材質: 鋼化玻璃, 適用品牌: Appl...
# 32  [品牌: Hope Year, 型號: L42198, 材質: 鋼化玻璃, 適用品牌: Ap...
# 12  [品牌: 記憶盒子, 材質: 鋼化玻璃, 適用品牌: Apple/蘋果, 貼膜類型: 前後膜...
# 38  [品牌: other/其他, 型號: O57180, 材質: 鋼化玻璃, 適用品牌: App...
# 22  [品牌: other/其他, 型號: R85865, 材質: 鋼化玻璃, 適用品牌: App...
#
#                                                 icons  \
# 30  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
# 32  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
# 12  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
# 38  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
# 22  [{'domClass': 'promotionBadge2', 'text': '滿額免運...
#
#                                                 image  inStock  ... review  \
# 30  https://img-ovs.alicdn.com/other/gsp/3fbe94b7b...     True  ...      0
# 32  https://img-ovs.alicdn.com/other/gsp/87bdc5726...     True  ...      0
# 12  https://img-ovs.alicdn.com/other/gsp/f0cb54a19...     True  ...      0
# 38  https://img-ovs.alicdn.com/other/gsp/ba58f18d9...     True  ...      0
# 22  https://img-ovs.alicdn.com/other/gsp/652be5f2a...     True  ...      0
#
#          sellerId sellerName          sku      skuId  \
# 30  2000000295003     淘寶海外精選  42908281_TW  517706862
# 32  2000000295003     淘寶海外精選  60982667_TW  759052797
# 12  2000000295003     淘寶海外精選  67172723_TW  835224364
# 38  2000000295003     淘寶海外精選  53098018_TW  653764337
# 22  2000000295003     淘寶海外精選  22886572_TW  252282990
#
#                                                  skus   tItemType  \
# 30  [{'id': '42908281_TW-517706863'}, {'id': '4290...  nt_product
# 32  [{'id': '60982667_TW-759052783'}, {'id': '6098...  nt_product
# 12  [{'id': '67172723_TW-835224366'}, {'id': '6717...  nt_product
# 38  [{'id': '53098018_TW-653764338'}, {'id': '5309...  nt_product
# 22  [{'id': '22886572_TW-252282990'}, {'id': '2288...  nt_product
#
#                                                thumbs  \
# 30  [{'image': 'https://img-ovs.alicdn.com/other/g...
# 32  [{'image': 'https://img-ovs.alicdn.com/other/g...
# 12  [{'image': 'https://img-ovs.alicdn.com/other/g...
# 38  [{'image': 'https://img-ovs.alicdn.com/other/g...
# 22  [{'image': 'https://img-ovs.alicdn.com/other/g...
#
#                                              utLogMap            voucherId
# 30  {'x_object_type': 'item', 'x_item_ids': '42908...
# 32  {'x_object_type': 'item', 'x_item_ids': '60982...
# 12  {'x_object_type': 'item', 'x_item_ids': '67172...
# 38  {'x_object_type': 'item', 'x_item_ids': '53098...
# 22  {'x_object_type': 'item', 'x_item_ids': '22886...
#
# [5 rows x 33 columns]

# %%
import requests
products = []
for i in range(1,6):
    res = requests.get(f'https://search.taobao.tw/catalog/?_keyori=ss&ajax=true&from=input&page={i}&q=iphone')
    jd = res.json()
    df = pandas.DataFrame(jd['mods']['listItems'])
    products.append(df)

# %%
df_all = pandas.concat(products)
# Out:
# /Users/davidchiu/.pyenv/versions/3.6.2/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
len(df_all)
# Out:
# 200

# %%
df_all.head()
# Out:
#                                        addToCartSkus     brandId brandName  \
# 0  [{'sku': '83152169_TW-932361562', 'skuId': '93...  1028900965     APPLE
# 1  [{'sku': '10454413_TW-101834700', 'skuId': '10...  1028900965     APPLE
# 2  [{'sku': '82236886_TW-931763775', 'skuId': '93...  1028900965     APPLE
# 3  [{'sku': '82267000_TW-931814143', 'skuId': '93...  1028900965     APPLE
# 4  [{'sku': '83271777_TW-932401733', 'skuId': '93...  1028900965     APPLE
#
#              categories           cheapest_sku  \
# 0  [30000002, 30000003]  83152169_TW-932361562
# 1  [30000002, 30000003]  10454413_TW-101834700
# 2  [30000002, 30000003]  82236886_TW-931763775
# 3  [30000002, 30000003]  82267000_TW-931814143
# 4  [30000002, 30000003]  83271777_TW-932401733
#
#                                           clickTrace  \
# 0  query:iphone;nid:83152169;src:LazadaMainSrp;rn...
# 1  query:iphone;nid:10454413;src:LazadaMainSrp;rn...
# 2  query:iphone;nid:82236886;src:LazadaMainSrp;rn...
# 3  query:iphone;nid:82267000;src:LazadaMainSrp;rn...
# 4  query:iphone;nid:83271777;src:LazadaMainSrp;rn...
#
#                                          description discount  \
# 0     [99 成新, 無盒, 附全新豆腐頭充電缐, 電池剛换新100%, 功能正常, 彰化可面交]      NaN
# 1                           [iphone 11 128G 綠色 全新未拆]      NaN
# 2                                               [現貨]      NaN
# 3                                               [現貨]      NaN
# 4  [特惠新品是當初原廠製造出來要讓有問題的手機去原廠更換的備用全新機, 盒裝沒有封裝 全新配件...      NaN
#
#                                                icons  \
# 0  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 1  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 2  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 3  [{'domClass': 'deliveryLocation', 'text': '本地'...
# 4  [{'domClass': 'deliveryLocation', 'text': '本地'...
#
#                                                image  ...  review  \
# 0  https://img-ovs.alicdn.com/p/89f591ae282fa85f2...  ...       0
# 1  https://img-ovs.alicdn.com/p/dd9c0925e43021ba7...  ...       0
# 2  https://img-ovs.alicdn.com/p/bf1ab965ebcbc6996...  ...       0
# 3  https://img-ovs.alicdn.com/p/d0587fdcc32a9f046...  ...       0
# 4  https://img-ovs.alicdn.com/p/94cc0ce7c26d4dedd...  ...       0
#
#         sellerId sellerName          sku      skuId  \
# 0  2000001816056  IPHONE 維修  83152169_TW  932361562
# 1  2000000868010     sonnga  10454413_TW  101834700
# 2  2000000874156  威訊3C手機批發網  82236886_TW  931763775
# 3  2000000874156  威訊3C手機批發網  82267000_TW  931814143
# 4  2000001297007  高雄樂3C-玉竹店  83271777_TW  932401733
#
#                                 skus   tItemType  \
# 0  [{'id': '83152169_TW-932361562'}]  nt_product
# 1  [{'id': '10454413_TW-101834700'}]  nt_product
# 2  [{'id': '82236886_TW-931763775'}]  nt_product
# 3  [{'id': '82267000_TW-931814143'}]  nt_product
# 4  [{'id': '83271777_TW-932401733'}]  nt_product
#
#                                               thumbs  \
# 0  [{'image': 'https://img-ovs.alicdn.com/p/89f59...
# 1  [{'image': 'https://img-ovs.alicdn.com/p/dd9c0...
# 2  [{'image': 'https://img-ovs.alicdn.com/p/bf1ab...
# 3  [{'image': 'https://img-ovs.alicdn.com/p/d0587...
# 4  [{'image': 'https://img-ovs.alicdn.com/p/94cc0...
#
#                                             utLogMap voucherId
# 0  {'x_object_type': 'item', 'x_item_ids': '83152...
# 1  {'x_object_type': 'item', 'x_item_ids': '10454...
# 2  {'x_object_type': 'item', 'x_item_ids': '82236...
# 3  {'x_object_type': 'item', 'x_item_ids': '82267...
# 4  {'x_object_type': 'item', 'x_item_ids': '83271...
#
# [5 rows x 36 columns]
